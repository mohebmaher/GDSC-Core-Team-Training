# %% [markdown]
# ## [Revising the Select Query I](https://www.hackerrank.com/challenges/revising-the-select-query/problem)

# %% [markdown]
# ### Problem statement:

# %% [markdown]
# Query all columns for all American cities in the `CITY` table with `POPULATION` larger than `100000`. The `COUNTRYCODE` for America is `"USA"`.
#
# The `CITY` table is described as follows:

# %% [markdown]
# ![image.png](attachment:764e8c8a-3699-4513-bbdb-288b40c1da21.png)

# %% [markdown]
# ### Solution:

# %% [markdown]
# `SELECT * FROM CITY WHERE POPULATION > 100000 AND COUNTRYCODE = 'USA';`

# %% [markdown]
# ## [Japanese Cities' Names](https://www.hackerrank.com/challenges/japanese-cities-name/problem)

# %% [markdown]
# ### Problem Statement

# %% [markdown]
# Query the names of all the Japanese cities in the `CITY` table. The `COUNTRYCODE` for Japan is `"JPN"`.
#
# The `CITY` table is described as follows:

# %% [markdown]
# ![image.png](attachment:6209c1ef-3dcb-4aba-ab53-6128dceffbe1.png)

# %% [markdown]
# ### Solution:

# %% [markdown]
# `SELECT NAME FROM CITY WHERE COUNTRYCODE ='JPN';`

# %% [markdown]
# ## [Weather Observation Station 4](https://www.hackerrank.com/challenges/weather-observation-station-4/problem)

# %% [markdown]
# ### Problem Statement

# %% [markdown]
# Find the difference between the total number of `CITY` entries in the table and the number of distinct `CITY` entries in the table.
#
# The `STATION` table is described as follows:

# %% [markdown]
# ![image.png](attachment:dd198aad-ba20-4e48-9c6f-9e4237239995.png)

# %% [markdown]
# ### Solution:

# %% [markdown]
# `SELECT COUNT(CITY) - COUNT(DISTINCT CITY) FROM STATION;`

# %% [markdown]
# ## [Average Population](https://www.hackerrank.com/challenges/average-population/problem)

# %% [markdown]
# ### Problem Statement

# %% [markdown]
# Query the average `POPULATION` for all cities in `CITY`, rounded down to the nearest integer.

# %% [markdown]
# ![image.png](attachment:fefbe393-01c7-431e-aefc-b4cad4fe239b.png)

# %% [markdown]
# ### Solution:

# %% [markdown]
# `SELECT FLOOR(AVG(POPULATION)) FROM CITY;`

# %% [markdown]
# ## [Weather Observation Station 8](https://www.hackerrank.com/challenges/weather-observation-station-8/problem)

# %% [markdown]
# ### Problem Statement

# %% [markdown]
# Query the list of `CITY` names from `STATION` which have vowels (i.e., a, e, i, o, and u) as both their first and last characters. Your result cannot contain duplicates.
#
# The `STATION` table is described as follows:

# %% [markdown]
# ![image.png](attachment:a811337d-556a-4acb-96ac-c7506ffb806d.png)

# %% [markdown]
# ### Solution:

# %% [markdown]
# `SELECT DISTINCT CITY FROM STATION`<br>
# `WHERE (CITY LIKE "[AEIOUaeiou]%") AND (CITY LIKE "%[AEIOUaeiou]");`

# %% [markdown]
# ## [Weather Observation Station 9](https://www.hackerrank.com/challenges/weather-observation-station-9/problem)

# %% [markdown]
# ### Problem Statement

# %% [markdown]
# Query the list of `CITY` names from `STATION` that do not start with vowels. Your result cannot contain duplicates.
#
# The `STATION` table is described as follows:

# %% [markdown]
# ![image.png](attachment:4e92b531-87eb-4480-a0a6-e75b56c01689.png)

# %% [markdown]
# ### Solution:

# %% [markdown]
# `SELECT DISTINCT city FROM STATION`<br>
# `WHERE NOT (CITY LIKE 'A%' OR CITY LIKE 'E%' OR CITY LIKE 'I%' OR CITY LIKE 'O%' OR CITY LIKE 'U%');`

# %% [markdown]
# ## [Employee Salaries](https://www.hackerrank.com/challenges/salary-of-employees/problem)

# %% [markdown]
# ### Problrm Statement:

# %% [markdown]
# Write a query that prints a list of employee names (i.e.: the name attribute) for employees in `Employee` having a salary greater than $2000 per month who have been employees for less than 10 months. Sort your result by ascending `employee_id`.
#
# The `Employee` table containing employee data for a company is described as follows:

# %% [markdown]
# ![image.png](attachment:c42d0626-96a5-4214-8ca6-052d1d6c14b6.png)

# %% [markdown]
# Where `employee_id` is an employee's ID number, name is their name, months is the total number of months they've been working for the company, and salary is the their monthly salary.

# %% [markdown]
# ![image.png](attachment:489fb4c4-69d3-4d1c-9e17-798e89fa1192.png)

# %% [markdown]
# Sample output:
#
# > `Angela`
#
# > `Michael`
#
# > `Todd`
#
# > `Joe`

# %% [markdown]
# Explanation:
# > - Angela has been an employee for 1 month and earns 3443 dollars per month.
# > - Michael has been an employee for 6 months and earns 2017 dollars per month.
# > - Todd has been an employee for 5 months and earns 3396 dollars per month.
# > - Joe has been an employee for 9 months and earns 3573 dollars per month.
# > - We order our output by ascending `employee_id`.

# %% [markdown]
# ### Solution:

# %% [markdown]
# `SELECT name FROM employee`<br>
# `WHERE salary > 2000 AND months < 10`<br>
# `ORDER BY employee_id;`

# %% [markdown]
# ## [Top Earners](https://www.hackerrank.com/challenges/earnings-of-employees/problem)

# %% [markdown]
# ### Problem Statement:

# %% [markdown]
# We define an employee's total earnings to be their monthly  worked, and the maximum total earnings to be the maximum total earnings for any employee in the `Employee` table. Write a query to find the maximum total earnings for all employees as well as the total number of employees who have maximum total earnings. Then print these values as 2 space-separated integers.
#
# The `Employee` table containing employee data for a company is described as follows:

# %% [markdown]
# ![image.png](attachment:61f244b8-ffef-4e30-aef2-e82bcd5fb6b6.png)

# %% [markdown]
# Where `employee_id` is an employee's ID number, name is their name, months is the total number of months they've been working for the company, and salary is the their monthly salary.

# %% [markdown]
# ![image.png](attachment:0e857057-6055-44e4-b38e-675e95140620.png)

# %% [markdown]
# Sample output:
# > `69952 1`

# %% [markdown]
# Explanation:
# > The table and earnings data is depicted in the following diagram:

# %% [markdown]
# ![image.png](attachment:76debb7f-6905-46fc-a681-6977129df3cd.png)

# %% [markdown]
# ### Solution:

# %% [markdown]
# `SELECT MAX(months * salary), COUNT(months * salary) FROM Employee`<br>
# `WHERE (months * salary) = (SELECT MAX(months * salary) FROM Employee);`

# %% [markdown]
# ## [Duplicate Emails](https://leetcode.com/problems/duplicate-emails/)

# %% [markdown]
# ### Problem Statement:

# %% [markdown]
# Table: `Person`

# %% [markdown]
# ![image.png](attachment:b8aaae5b-b7e3-4731-8706-1ab5d5ed2d23.png)

# %% [markdown]
# `id` is the primary key column for this table. Each row of this table contains an email. The emails will not contain uppercase letters.
#
# Write an SQL query to report all the duplicate emails. Note that it's guaranteed that the `email` field is not NULL.
#
# Return the result table in any order.

# %% [markdown]
# ### Solution:

# %% [markdown]
# `SELECT email FROM Person`<br>
# `GROUP BY email`<br>
# `HAVING COUNT(*) > 1;`

# %% [markdown]
# ## [Second Highest Salary](https://leetcode.com/problems/second-highest-salary/)

# %% [markdown]
# ### Problem Statement:

# %% [markdown]
# Table: `Employee`

# %% [markdown]
# ![image.png](attachment:37cd4b7d-978d-4d34-8a06-b6e4846b2b65.png)

# %% [markdown]
# `id` is the primary key column for this table. Each row of this table contains information about the salary of an employee.
#
# Write an SQL query to report the second highest salary from the `Employee` table. If there is no second highest salary, the query should report `null`.

# %% [markdown]
# ### Solution:

# %% [markdown]
# `SELECT MAX(salary) AS SecondHighestSalary FROM Employee`<br>
# `WHERE salary NOT IN (SELECT MAX(salary) FROM Employee);`

# %% [markdown]
# ## [Rising Temperature](https://leetcode.com/problems/rising-temperature/)

# %% [markdown]
# ### Problem Statement:

# %% [markdown]
# Table: `Weather`

# %% [markdown]
# ![image.png](attachment:9b001fde-0e60-432d-b1dd-0b4b300c075f.png)

# %% [markdown]
# `id` is the primary key for this table. This table contains information about the temperature on a certain day.
#
# Write an SQL query to find all dates' `Id` with higher temperatures compared to its previous dates (yesterday).
#
# Return the result table in **any order**.

# %% [markdown]
# ### Solution:

# %% [markdown]
# `SELECT w2.id FROM Weather w1`<br>
# `JOIN Weather w2 ON DATEDIFF(w1.recordDate, w2.recordDate) = -1`<br>
# `WHERE w2.temperature > w1.temperature;`

# %% [markdown]
# ## [Not Boring Movies](https://leetcode.com/problems/not-boring-movies/)

# %% [markdown]
# ### Problem Statement:

# %% [markdown]
# Table: `Cinema`

# %% [markdown]
# ![image.png](attachment:78c8cca0-5ebc-4fd5-b6db-9964549fd00b.png)

# %% [markdown]
# `id` is the primary key for this table. Each row contains information about the name of a movie, its genre, and its rating. rating is a 2 decimal places float in the range `[0, 10]`.
#
# Write an SQL query to report the movies with an odd-numbered ID and a description that is not `"boring"`.
#
# Return the result table ordered by rating in **descending order**.

# %% [markdown]
# ### Solution:

# %% [markdown]
# `SELECT * FROM Cinema`<br>
# `WHERE id % 2 = 1 AND description != "boring"`<br>
# `ORDER BY rating DESC;`

# %% [markdown]
# ## [Sales Person](https://leetcode.com/problems/sales-person/)

# %% [markdown]
# ### Problem statement:

# %% [markdown]
# Table: `SalesPerson`

# %% [markdown]
# ![image.png](attachment:26de4f15-68b8-4e00-8741-5924676a55bb.png)

# %% [markdown]
# `sales_id` is the primary key column for this table. Each row of this table indicates the name and the ID of a salesperson alongside their salary, commission rate, and hire date.

# %% [markdown]
# Table: `Orders`

# %% [markdown]
# ![image.png](attachment:cb62b980-5c98-44a8-9503-2895e2a961e4.png)

# %% [markdown]
# `order_id` is the primary key column for this table. `com_id` is a foreign key to com_id from the Company table. `sales_id` is a foreign key to `sales_id` from the SalesPerson table. Each row of this table contains information about one order. This includes the ID of the company, the ID of the salesperson, the date of the order, and the amount paid.

# %% [markdown]
# Write an SQL query to report the names of all the salespersons who did not have any orders related to the company with the name `"RED"`.
#
# Return the result table in **any order**.

# %% [markdown]
# ### Solution:

# %% [markdown]
# `SELECT s.name FROM SalesPerson s`<br>
# `WHERE s.name NOT IN (SELECT s.name FROM Orders o`<br>
# `                    INNER JOIN Company c ON c.com_id = o.com_id`<br>
# `                    LEFT JOIN SalesPerson s ON s.sales_id = o.sales_id`<br>
# `                    WHERE c.name = "RED");`

# %% [markdown]
# ## [Game Play Analysis I](https://leetcode.com/problems/game-play-analysis-i/)

# %% [markdown]
# ### Problem statement:

# %% [markdown]
# Table: `Activity`

# %% [markdown]
# ![image.png](attachment:dc97612a-4369-4776-9960-51d72921e9c0.png)

# %% [markdown]
# (`player_id`, `event_date`) is the primary key of this table. This table shows the activity of players of some games. Each row is a record of a player who logged in and played a number of games (possibly 0) before logging out on someday using some device.
#
# Write an SQL query to report the first login date for each player.
#
# Return the result table in **any order**.

# %% [markdown]
# ### Solution:

# %% [markdown]
# `SELECT player_id, MIN(event_date) AS first_login FROM Activity`<br>
# `GROUP BY player_id;`
